# %%
# !kaggle datasets download -d andrewmvd/liver-tumor-segmentation
# !kaggle datasets download -d harunurroshid12/resnet50
# Out:
# Dataset URL: https://www.kaggle.com/datasets/andrewmvd/liver-tumor-segmentation
# License(s): Attribution-NonCommercial-NoDerivatives 4.0 International (CC BY-NC-ND 4.0)
# Downloading liver-tumor-segmentation.zip to /content
# 100% 4.82G/4.84G [00:29<00:00, 196MB/s]
# 100% 4.84G/4.84G [00:29<00:00, 176MB/s]
# Dataset URL: https://www.kaggle.com/datasets/harunurroshid12/resnet50
# License(s): unknown
# Downloading resnet50.zip to /content
#  99% 83.0M/83.5M [00:00<00:00, 157MB/s]
# 100% 83.5M/83.5M [00:00<00:00, 136MB/s]

# %%
# !unzip -o liver-tumor-segmentation.zip -d /content/liver_tumor_segmentation
# !unzip -o resnet50.zip -d /content/resnet50
# Out:
# Archive:  liver-tumor-segmentation.zip
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-0.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-1.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-10.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-100.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-101.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-102.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-103.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-104.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-105.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-106.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-107.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-108.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-109.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-11.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-110.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-111.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-112.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-113.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-114.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-115.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-116.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-117.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-118.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-119.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-12.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-120.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-121.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-122.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-123.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-124.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-125.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-126.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-127.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-128.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-129.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-13.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-130.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-14.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-15.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-16.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-17.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-18.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-19.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-2.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-20.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-21.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-22.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-23.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-24.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-25.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-26.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-27.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-28.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-29.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-3.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-30.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-31.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-32.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-33.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-34.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-35.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-36.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-37.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-38.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-39.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-4.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-40.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-41.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-42.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-43.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-44.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-45.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-46.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-47.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-48.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-49.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-5.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-50.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-51.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-52.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-53.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-54.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-55.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-56.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-57.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-58.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-59.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-6.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-60.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-61.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-62.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-63.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-64.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-65.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-66.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-67.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-68.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-69.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-7.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-70.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-71.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-72.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-73.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-74.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-75.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-76.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-77.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-78.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-79.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-8.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-80.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-81.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-82.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-83.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-84.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-85.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-86.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-87.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-88.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-89.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-9.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-90.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-91.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-92.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-93.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-94.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-95.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-96.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-97.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-98.nii
#   inflating: /content/liver_tumor_segmentation/segmentations/segmentation-99.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt1/volume-0.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt1/volume-1.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt1/volume-10.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt1/volume-2.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt1/volume-3.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt1/volume-4.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt1/volume-5.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt1/volume-6.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt1/volume-7.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt1/volume-8.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt1/volume-9.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt2/volume-11.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt2/volume-12.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt2/volume-13.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt2/volume-14.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt2/volume-15.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt2/volume-16.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt2/volume-17.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt2/volume-18.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt2/volume-19.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt2/volume-20.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt3/volume-21.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt3/volume-22.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt3/volume-23.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt3/volume-24.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt3/volume-25.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt3/volume-26.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt3/volume-27.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt3/volume-28.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt3/volume-29.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt3/volume-30.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt4/volume-31.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt4/volume-32.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt4/volume-33.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt4/volume-34.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt4/volume-35.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt4/volume-36.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt4/volume-37.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt4/volume-38.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt4/volume-39.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt4/volume-40.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt5/volume-41.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt5/volume-42.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt5/volume-43.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt5/volume-44.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt5/volume-45.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt5/volume-46.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt5/volume-47.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt5/volume-48.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt5/volume-49.nii
#   inflating: /content/liver_tumor_segmentation/volume_pt5/volume-50.nii
# Archive:  resnet50.zip
#   inflating: /content/resnet50/resnet50_weights.h5

# %%
import os
import pandas as pd

# Directories of the datasets
dir1 = '/content/liver_tumor_segmentation'
dir2 = '/content/resnet50'

# Collect files from both directories
files = []
for dirname, _, filenames in os.walk(dir1):
    for filename in filenames:
        files.append((dirname, filename))

for dirname, _, filenames in os.walk(dir2):
    for filename in filenames:
        files.append((dirname, filename))

# Create a DataFrame
df_files = pd.DataFrame(files, columns=['dirname', 'filename'])

# %%
# Sort the DataFrame
df_files = df_files.sort_values(by='filename')

# Display the sorted DataFrame
print(df_files.head())
# Out:
#                                              dirname              filename
# 182                                /content/resnet50   resnet50_weights.h5
# 83   /content/liver_tumor_segmentation/segmentations    segmentation-0.nii
# 36   /content/liver_tumor_segmentation/segmentations    segmentation-1.nii
# 64   /content/liver_tumor_segmentation/segmentations   segmentation-10.nii
# 48   /content/liver_tumor_segmentation/segmentations  segmentation-100.nii

# %%
# !pip install nibabel
import numpy as np #allow efficient mathematical operations on arrays.Used for numerical computations, linear algebra, and data manipulation.
import pandas as pd #provides data structures (Series and DataFrame) for handling and analyzing tabular data
import os
import matplotlib.pyplot as plt # for creating visualizations
import glob #Used for batch processing files with similar names or extensions
import nibabel as nib #neuroscience and medical imaging research.
import cv2 #rovides functions for image manipulation, feature extraction, and object detection
import imageio #for reading and writing image data, oading images into memory, creating animations, and saving visualizations
from tqdm.notebook import tqdm #Useful for tracking the progress of time-consuming operations (e.g., data processing, downloads).
from ipywidgets import * #for creating dynamic visualizations and interactive controls
from PIL import Image #for creating dynamic visualizations and interactive controls
from fastai.basics import * #for building custom models and working with data pipelines
from fastai.vision.all import * #for image classification, and segmentation
from fastai.data.transforms import * #provides various data transformation functions
import random #for simulations, shuffling data, and creating random samples
from matplotlib.pyplot import figure #Used for creating charts, histograms, scatter plots, and other types of graphs
import nibabel as nib #used for reading and writing NIfTI files
from sklearn.model_selection import train_test_split #to split a dataset into training and testing sets
from tensorflow.keras.layers import *#use to build the architecture of a neural network model.
from tensorflow.keras.models import Model #llows to create a model by specifying its inputs and outputs.
from tensorflow.keras.optimizers import Adam
# Out:
# Collecting nibabel
#   Downloading nibabel-5.3.2-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.10/dist-packages (from nibabel) (6.4.5)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from nibabel) (1.26.4)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.10/dist-packages (from nibabel) (24.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.10/dist-packages (from nibabel) (4.12.2)
# Downloading nibabel-5.3.2-py3-none-any.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 27.7 MB/s eta 0:00:00
# Installing collected packages: nibabel
# Successfully installed nibabel-5.3.2

# %%
# Map CT scan and label

df_files["mask_dirname"]  = ""
df_files["mask_filename"] = ""

for i in range(131):
    ct = f"volume-{i}.nii"
    mask = f"segmentation-{i}.nii"

    df_files.loc[df_files['filename'] == ct, 'mask_filename'] = mask
    df_files.loc[df_files['filename'] == ct, 'mask_dirname'] = "/content/liver_tumor_segmentation"

# drop segment rows
df_files = df_files[df_files.mask_filename != ''].sort_values(by=['filename']).reset_index(drop=True)

df_files
# Out:
#                                          dirname       filename  \
# 0   /content/liver_tumor_segmentation/volume_pt1   volume-0.nii
# 1   /content/liver_tumor_segmentation/volume_pt1   volume-1.nii
# 2   /content/liver_tumor_segmentation/volume_pt1  volume-10.nii
# 3   /content/liver_tumor_segmentation/volume_pt2  volume-11.nii
# 4   /content/liver_tumor_segmentation/volume_pt2  volume-12.nii
# 5   /content/liver_tumor_segmentation/volume_pt2  volume-13.nii
# 6   /content/liver_tumor_segmentation/volume_pt2  volume-14.nii
# 7   /content/liver_tumor_segmentation/volume_pt2  volume-15.nii
# 8   /content/liver_tumor_segmentation/volume_pt2  volume-16.nii
# 9   /content/liver_tumor_segmentation/volume_pt2  volume-17.nii
# 10  /content/liver_tumor_segmentation/volume_pt2  volume-18.nii
# 11  /content/liver_tumor_segmentation/volume_pt2  volume-19.nii
# 12  /content/liver_tumor_segmentation/volume_pt1   volume-2.nii
# 13  /content/liver_tumor_segmentation/volume_pt2  volume-20.nii
# 14  /content/liver_tumor_segmentation/volume_pt3  volume-21.nii
# 15  /content/liver_tumor_segmentation/volume_pt3  volume-22.nii
# 16  /content/liver_tumor_segmentation/volume_pt3  volume-23.nii
# 17  /content/liver_tumor_segmentation/volume_pt3  volume-24.nii
# 18  /content/liver_tumor_segmentation/volume_pt3  volume-25.nii
# 19  /content/liver_tumor_segmentation/volume_pt3  volume-26.nii
# 20  /content/liver_tumor_segmentation/volume_pt3  volume-27.nii
# 21  /content/liver_tumor_segmentation/volume_pt3  volume-28.nii
# 22  /content/liver_tumor_segmentation/volume_pt3  volume-29.nii
# 23  /content/liver_tumor_segmentation/volume_pt1   volume-3.nii
# 24  /content/liver_tumor_segmentation/volume_pt3  volume-30.nii
# 25  /content/liver_tumor_segmentation/volume_pt4  volume-31.nii
# 26  /content/liver_tumor_segmentation/volume_pt4  volume-32.nii
# 27  /content/liver_tumor_segmentation/volume_pt4  volume-33.nii
# 28  /content/liver_tumor_segmentation/volume_pt4  volume-34.nii
# 29  /content/liver_tumor_segmentation/volume_pt4  volume-35.nii
# 30  /content/liver_tumor_segmentation/volume_pt4  volume-36.nii
# 31  /content/liver_tumor_segmentation/volume_pt4  volume-37.nii
# 32  /content/liver_tumor_segmentation/volume_pt4  volume-38.nii
# 33  /content/liver_tumor_segmentation/volume_pt4  volume-39.nii
# 34  /content/liver_tumor_segmentation/volume_pt1   volume-4.nii
# 35  /content/liver_tumor_segmentation/volume_pt4  volume-40.nii
# 36  /content/liver_tumor_segmentation/volume_pt5  volume-41.nii
# 37  /content/liver_tumor_segmentation/volume_pt5  volume-42.nii
# 38  /content/liver_tumor_segmentation/volume_pt5  volume-43.nii
# 39  /content/liver_tumor_segmentation/volume_pt5  volume-44.nii
# 40  /content/liver_tumor_segmentation/volume_pt5  volume-45.nii
# 41  /content/liver_tumor_segmentation/volume_pt5  volume-46.nii
# 42  /content/liver_tumor_segmentation/volume_pt5  volume-47.nii
# 43  /content/liver_tumor_segmentation/volume_pt5  volume-48.nii
# 44  /content/liver_tumor_segmentation/volume_pt5  volume-49.nii
# 45  /content/liver_tumor_segmentation/volume_pt1   volume-5.nii
# 46  /content/liver_tumor_segmentation/volume_pt5  volume-50.nii
# 47  /content/liver_tumor_segmentation/volume_pt1   volume-6.nii
# 48  /content/liver_tumor_segmentation/volume_pt1   volume-7.nii
# 49  /content/liver_tumor_segmentation/volume_pt1   volume-8.nii
# 50  /content/liver_tumor_segmentation/volume_pt1   volume-9.nii
#
#                          mask_dirname        mask_filename
# 0   /content/liver_tumor_segmentation   segmentation-0.nii
# 1   /content/liver_tumor_segmentation   segmentation-1.nii
# 2   /content/liver_tumor_segmentation  segmentation-10.nii
# 3   /content/liver_tumor_segmentation  segmentation-11.nii
# 4   /content/liver_tumor_segmentation  segmentation-12.nii
# 5   /content/liver_tumor_segmentation  segmentation-13.nii
# 6   /content/liver_tumor_segmentation  segmentation-14.nii
# 7   /content/liver_tumor_segmentation  segmentation-15.nii
# 8   /content/liver_tumor_segmentation  segmentation-16.nii
# 9   /content/liver_tumor_segmentation  segmentation-17.nii
# 10  /content/liver_tumor_segmentation  segmentation-18.nii
# 11  /content/liver_tumor_segmentation  segmentation-19.nii
# 12  /content/liver_tumor_segmentation   segmentation-2.nii
# 13  /content/liver_tumor_segmentation  segmentation-20.nii
# 14  /content/liver_tumor_segmentation  segmentation-21.nii
# 15  /content/liver_tumor_segmentation  segmentation-22.nii
# 16  /content/liver_tumor_segmentation  segmentation-23.nii
# 17  /content/liver_tumor_segmentation  segmentation-24.nii
# 18  /content/liver_tumor_segmentation  segmentation-25.nii
# 19  /content/liver_tumor_segmentation  segmentation-26.nii
# 20  /content/liver_tumor_segmentation  segmentation-27.nii
# 21  /content/liver_tumor_segmentation  segmentation-28.nii
# 22  /content/liver_tumor_segmentation  segmentation-29.nii
# 23  /content/liver_tumor_segmentation   segmentation-3.nii
# 24  /content/liver_tumor_segmentation  segmentation-30.nii
# 25  /content/liver_tumor_segmentation  segmentation-31.nii
# 26  /content/liver_tumor_segmentation  segmentation-32.nii
# 27  /content/liver_tumor_segmentation  segmentation-33.nii
# 28  /content/liver_tumor_segmentation  segmentation-34.nii
# 29  /content/liver_tumor_segmentation  segmentation-35.nii
# 30  /content/liver_tumor_segmentation  segmentation-36.nii
# 31  /content/liver_tumor_segmentation  segmentation-37.nii
# 32  /content/liver_tumor_segmentation  segmentation-38.nii
# 33  /content/liver_tumor_segmentation  segmentation-39.nii
# 34  /content/liver_tumor_segmentation   segmentation-4.nii
# 35  /content/liver_tumor_segmentation  segmentation-40.nii
# 36  /content/liver_tumor_segmentation  segmentation-41.nii
# 37  /content/liver_tumor_segmentation  segmentation-42.nii
# 38  /content/liver_tumor_segmentation  segmentation-43.nii
# 39  /content/liver_tumor_segmentation  segmentation-44.nii
# 40  /content/liver_tumor_segmentation  segmentation-45.nii
# 41  /content/liver_tumor_segmentation  segmentation-46.nii
# 42  /content/liver_tumor_segmentation  segmentation-47.nii
# 43  /content/liver_tumor_segmentation  segmentation-48.nii
# 44  /content/liver_tumor_segmentation  segmentation-49.nii
# 45  /content/liver_tumor_segmentation   segmentation-5.nii
# 46  /content/liver_tumor_segmentation  segmentation-50.nii
# 47  /content/liver_tumor_segmentation   segmentation-6.nii
# 48  /content/liver_tumor_segmentation   segmentation-7.nii
# 49  /content/liver_tumor_segmentation   segmentation-8.nii
# 50  /content/liver_tumor_segmentation   segmentation-9.nii

# %%
import os
print(os.listdir("/content/liver_tumor_segmentation"))
# Out:
# ['volume_pt1', 'volume_pt4', 'segmentations', 'volume_pt2', 'volume_pt3', 'volume_pt5']

# %%
# Ensure the 'mask_dirname' only contains '/segmentations'
df_files["mask_dirname"] = "/content/liver_tumor_segmentation/segmentations"

# Verify the full file path for sample 5 (segmentation-5.nii)
sample = 5
file_path = df_files.loc[sample, 'mask_dirname'] + "/segmentation-" + str(sample) + ".nii"
print(f"Full file path: {file_path}")

# Try loading the file again
import nibabel as nib
ct_scan = nib.load(file_path)  # Load the NIfTI file
array = ct_scan.get_fdata()  # Get the data as a numpy array
print(f"Array shape: {array.shape}")
# Out:
# Full file path: /content/liver_tumor_segmentation/segmentations/segmentation-5.nii
# Array shape: (512, 512, 537)

# %%
import nibabel as nib
def read_nii(file_path):
    nii_image = nib.load(file_path)
    return nii_image.get_fdata()
sample = 40

# Read a CT scan file using the 'read_nii' function
sample_ct = read_nii(df_files.loc[sample,'dirname']+"/"+df_files.loc[sample,'filename'])

# Read a Mask scan file using the 'read_nii' function
sample_mask = read_nii(df_files.loc[sample,'mask_dirname']+"/"+df_files.loc[sample,'mask_filename'])

# Display the shape of the CT and Mask images
print(f'CT Shape:   {sample_ct.shape}\nMask Shape: {sample_mask.shape}')
# Out:
# CT Shape:   (512, 512, 74)
# Mask Shape: (512, 512, 74)

# %%
# Preprocess the nii file
#it extends the functionality of PyTorch's
dicom_windows = types.SimpleNamespace(
    brain=(80,40),
    subdural=(254,100),
    stroke=(8,32),
    brain_bone=(2800,600),
    brain_soft=(375,40),
    lungs=(1500,-600),
    mediastinum=(350,50),
    abdomen_soft=(400,50),
    liver=(150,30),
    spine_soft=(250,50),
    spine_bone=(1800,400),
    custom = (200,60)
)

# %%
#This decorator is used to add a new method windowed to the Tensor class.
@patch
#The result is a tensor with pixel values scaled between 0 and 1, representing the windowed image.
def windowed(self:Tensor, w, l):
    px = self.clone()
    px_min = l - w//2
    px_max = l + w//2
    px[px<px_min] = px_min
    px[px>px_max] = px_max
    return (px-px_min) / (px_max-px_min)

figure(figsize=(8, 6), dpi=100)
#It appears you're applying the liver window settings (dicom_windows.liver) to the slice to visualize the liver tissue in the CT scan
plt.imshow(tensor(sample_ct[..., 55].astype(np.float32)).windowed(*dicom_windows.liver), cmap=plt.cm.bone);

# %%
"""# 3.2- Read 'nii' File and Show Original Data"""

# this code read nii file and show original data

# Load the NIfTI file containing the volume
volume_nifti = nib.load('/content/liver_tumor_segmentation/volume_pt1/volume-0.nii')

# Load the NIfTI file containing the segmentation image
segmentation_nifti = nib.load('/content/liver_tumor_segmentation/segmentations/segmentation-0.nii')

# Extract the data arrays from the NIfTI files
volume_data = volume_nifti.get_fdata()
segmentation_data = segmentation_nifti.get_fdata()

# Choose a slice to display (e.g., slice 0 along the first axis)
slice_index = 0

# Plot the volume slice
plt.subplot(1, 2, 1)
plt.imshow(volume_data[..., slice_index], cmap='gray')
plt.title('Volume Slice {}'.format(slice_index))
plt.axis('off')

# Plot the segmentation slice
plt.subplot(1, 2, 2)
plt.imshow(segmentation_data[..., slice_index], cmap='jet')  # Adjust the colormap as needed
plt.title('Segmentation Slice {}'.format(slice_index))
plt.axis('off')

plt.show()

def plot_sample(array_list, color_map = 'nipy_spectral'):
    '''
    Plots and a slice with all available annotations
    '''
    fig = plt.figure(figsize=(20,16), dpi=100)

    plt.subplot(1,4,1)
    plt.imshow(array_list[0], cmap='bone')
    plt.title('Original Image')
    plt.axis('off')
    #presumably a medical image, converts it to a PyTorch tensor, and applies windowing using the parameters from dicom_windows.liver. It uses the 'bone' color map for visualization, adds a title "Windowed Image", and turns off the axis.
    plt.subplot(1,4,2)
    plt.imshow(tensor(array_list[0].astype(np.float32)).windowed(*dicom_windows.liver), cmap='bone');
    plt.title('Windowed Image')
    plt.axis('off')

    plt.subplot(1,4,3)
    plt.imshow(array_list[1], alpha=0.5, cmap=color_map)
    plt.title('Mask')
    plt.axis('off')

    plt.subplot(1,4,4)
    plt.imshow(array_list[0], cmap='bone')
    plt.imshow(array_list[1], alpha=0.5, cmap=color_map)
    plt.title('Liver & Mask')
    plt.axis('off')

    plt.show()

sample = 40

sample_slice = tensor(sample_ct[...,sample].astype(np.float32))

plot_sample([sample_ct[..., sample],
             sample_mask[..., sample]])

# %%
"""# 3.3- Preprocessing Functions"""

# Preprocessing functions
class TensorCTScan(TensorImageBW): _show_args = {'cmap':'bone'} #a subclass of a PyTorch Tensor designed to handle black-and-white images.

@patch
def freqhist_bins(self: Tensor, n_bins=100):
    "A function to split the range of pixel values into groups, such that each group has around the same number of pixels"
    imsd = self.reshape(-1).sort()[0]  # Replace .view(-1) with .reshape(-1)
    t = torch.cat([tensor([0.001]),
                   torch.arange(n_bins).float()/n_bins + (1/2/n_bins),
                   tensor([0.999])])
    t = (len(imsd) * t).long()
    return imsd[t].unique()

@patch
def hist_scaled(self:Tensor, brks=None):
    "Scales a tensor using `freqhist_bins` to values between 0 and 1"
    if self.device.type=='cuda': return self.hist_scaled_pt(brks)
    if brks is None: brks = self.freqhist_bins()
    ys = np.linspace(0., 1., len(brks))
    x = self.numpy().flatten()
    x = np.interp(x, brks.numpy(), ys)
    return tensor(x).reshape(self.shape).clamp(0.,1.)


@patch
def to_nchan(x:Tensor, wins, bins=None):
    res = [x.windowed(*win) for win in wins]
    if not isinstance(bins,int) or bins!=0: res.append(x.hist_scaled(bins).clamp(0,1))
    dim = [0,1][x.dim()==3]
    return TensorCTScan(torch.stack(res, dim=dim))

@patch
def save_jpg(x:(Tensor), path, wins, bins=None, quality=120): #unction to convert the tensor to a multi-channel image suitable for saving as a JPG.The image is saved with the specified quality.
    fn = Path(path).with_suffix('.jpg')
    x = (x.to_nchan(wins, bins)*255).byte()
    im = Image.fromarray(x.permute(1,2,0).numpy(), mode=['RGB','CMYK'][x.shape[0]==4])
    im.save(fn, quality=quality)

_,axs = subplots(1,1)

sample_slice.save_jpg('test.jpg', [dicom_windows.liver, dicom_windows.custom])
show_image(Image.open('test.jpg'), ax=axs[0], figsize=(8, 6))
# Out:
# <Axes: >

# %%
"""# 4- Generate *Unet Training* Image From 'nii' File"""

GENERATE_JPG_FILES = True

if GENERATE_JPG_FILES:

    path = Path(".")

    os.makedirs('train_images', exist_ok=True)
    os.makedirs('train_masks', exist_ok=True)

    ## test folder
    os.makedirs('test_images', exist_ok=True)
    os.makedirs('test_masks', exist_ok=True)

    # Split the data into train and test sets
    train_df, test_df = train_test_split(df_files, test_size=0.1, random_state=42)

    # Check if train_df is empty
    print("Length of train_df:", len(train_df))

    # Reset index for contiguous indices
    train_df = train_df.reset_index(drop=True)
    # Check if test_df is empty
    print("Length of test_df:", len(test_df))
    test_df = test_df.reset_index(drop=True)

    # Loop for training set
    for ii in tqdm(range(len(train_df))):
        curr_ct = read_nii(train_df.loc[ii, 'dirname'] + "/" + train_df.loc[ii, 'filename'])
        curr_mask = read_nii(train_df.loc[ii, 'mask_dirname'] + "/" + train_df.loc[ii, 'mask_filename'])
        curr_file_name = str(train_df.loc[ii, 'filename']).split('.')[0]
        curr_dim = curr_ct.shape[2]

        for curr_slice in range(0, curr_dim, 2):
            data = tensor(curr_ct[..., curr_slice].astype(np.float32))
            mask = Image.fromarray(curr_mask[..., curr_slice].astype('uint8'), mode="L")
            data.save_jpg(f"train_images/{curr_file_name}_slice_{curr_slice}.jpg", [dicom_windows.liver, dicom_windows.custom])
            mask.save(f"train_masks/{curr_file_name}_slice_{curr_slice}_mask.png")

    ### test image save
    for ii in tqdm(range(len(test_df))):
        curr_ct = read_nii(test_df.loc[ii, 'dirname'] + "/" + test_df.loc[ii, 'filename'])
        curr_mask = read_nii(test_df.loc[ii, 'mask_dirname'] + "/" + test_df.loc[ii, 'mask_filename'])
        curr_file_name = str(test_df.loc[ii, 'filename']).split('.')[0]
        curr_dim = curr_ct.shape[2]

        for curr_slice in range(0, curr_dim, 2):
            data = tensor(curr_ct[..., curr_slice].astype(np.float32))
            mask = Image.fromarray(curr_mask[..., curr_slice].astype('uint8'), mode="L")
            data.save_jpg(f"test_images/{curr_file_name}_slice_{curr_slice}.jpg", [dicom_windows.liver, dicom_windows.custom])
            mask.save(f"test_masks/{curr_file_name}_slice_{curr_slice}_mask.png")

else:
    path = Path("../input/liver-segmentation-with-fastai-v2")  # read jpg from saved kernel output
# Out:
# Length of train_df: 45
# Length of test_df: 6
#   0%|          | 0/45 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]

# %%
"""# 4.1- Show Data"""

print("\nFirst few rows of Training Set:")
print(train_df.head())

print("\nFirst few rows of Testing Set:")
print(test_df.head())

print("\ntrain df data shape:")
print(train_df.shape)

print("\ntest df data shape:")
print(test_df.shape)
# Out:
# First few rows of Training Set:
#                                         dirname       filename  \
# 0  /content/liver_tumor_segmentation/volume_pt3  volume-24.nii
# 1  /content/liver_tumor_segmentation/volume_pt4  volume-38.nii
# 2  /content/liver_tumor_segmentation/volume_pt2  volume-11.nii
# 3  /content/liver_tumor_segmentation/volume_pt4  volume-36.nii
# 4  /content/liver_tumor_segmentation/volume_pt2  volume-20.nii
#
#                                       mask_dirname        mask_filename
# 0  /content/liver_tumor_segmentation/segmentations  segmentation-24.nii
# 1  /content/liver_tumor_segmentation/segmentations  segmentation-38.nii
# 2  /content/liver_tumor_segmentation/segmentations  segmentation-11.nii
# 3  /content/liver_tumor_segmentation/segmentations  segmentation-36.nii
# 4  /content/liver_tumor_segmentation/segmentations  segmentation-20.nii
#
# First few rows of Testing Set:
#                                         dirname       filename  \
# 0  /content/liver_tumor_segmentation/volume_pt5  volume-48.nii
# 1  /content/liver_tumor_segmentation/volume_pt5  volume-45.nii
# 2  /content/liver_tumor_segmentation/volume_pt5  volume-50.nii
# 3  /content/liver_tumor_segmentation/volume_pt1   volume-2.nii
# 4  /content/liver_tumor_segmentation/volume_pt3  volume-30.nii
#
#                                       mask_dirname        mask_filename
# 0  /content/liver_tumor_segmentation/segmentations  segmentation-48.nii
# 1  /content/liver_tumor_segmentation/segmentations  segmentation-45.nii
# 2  /content/liver_tumor_segmentation/segmentations  segmentation-50.nii
# 3  /content/liver_tumor_segmentation/segmentations   segmentation-2.nii
# 4  /content/liver_tumor_segmentation/segmentations  segmentation-30.nii
#
# train df data shape:
# (45, 4)
#
# test df data shape:
# (6, 4)

# %%
"""# 5- Resizing Images"""
import os
# Set the directories
train_images_dir = './train_images'
train_masks_dir = './train_masks'

# Get the list of image file names
all_image_file_names = sorted(os.listdir(train_images_dir))

# Determine the sample size
sample_size = min(9000, len(all_image_file_names))

# Randomly select images
selected_image_file_names = random.sample(all_image_file_names, sample_size)

# Load selected images and masks with resizing nd converted to numpy arrays
target_size = (128, 128)
train_images = [np.array(Image.open(os.path.join(train_images_dir, fname)).resize(target_size)) for fname in selected_image_file_names]

# Adjust file extension for masks
mask_file_names = [fname.replace('.jpg', '_mask.png') for fname in selected_image_file_names]
train_masks = [np.array(Image.open(os.path.join(train_masks_dir, fname)).resize(target_size)) for fname in mask_file_names]

# Convert the lists to numpy arrays  for further processing
train_images = np.array(train_images)
train_masks = np.array(train_masks)

# Normalize images to [0, 1]
train_images =train_images / 255.0

# Reshape masks to include a channel dimension
train_masks =train_masks.reshape((train_masks.shape[0], train_masks.shape[1], train_masks.shape[2], 1))

# Set the directories
test_images_dir = './test_images'
test_masks_dir = './test_masks'

# Get the list of image file names
all_image_file_names = sorted(os.listdir(test_images_dir))

# Determine the sample size
sample_size = min(9000, len(all_image_file_names))

# Randomly select images
selected_image_file_names = random.sample(all_image_file_names, sample_size)

# Load selected images and masks with resizing
target_size = (128, 128)
test_images = [np.array(Image.open(os.path.join(test_images_dir, fname)).resize(target_size)) for fname in selected_image_file_names]

# Adjust file extension for masks
mask_file_names = [fname.replace('.jpg', '_mask.png') for fname in selected_image_file_names]
test_masks = [np.array(Image.open(os.path.join(test_masks_dir, fname)).resize(target_size)) for fname in mask_file_names]

# Convert the lists to numpy arrays
test_images = np.array(test_images)
test_masks = np.array(test_masks)

# Normalize images to [0, 1]
test_images =test_images / 255.0

# Reshape masks to include a channel dimension
test_masks =test_masks.reshape((test_masks.shape[0], test_masks.shape[1], test_masks.shape[2], 1))

print(f"Train image ={len(train_images)} Test image={len(test_images)}")
print(f"Train mask ={len(train_masks)}  Test mask={len(test_masks)}")
# Out:
# Train image =8556 Test image=699
# Train mask =8556  Test mask=699

# %%
"""# 6- Split Data Train Test and Validation"""

x_valid, x_test, y_valid, y_test = train_test_split(test_images, test_masks, test_size=1/3, random_state=42)

print(f"train image={train_images.shape} and train_masks={train_masks.shape}")
print(f"X valid shape ={x_valid.shape} x_test={x_test.shape}")
print(f"y valid shape ={y_valid.shape}  y_test={y_test.shape}")

"""# 6.1- Display Random Images and Masks"""

def display_images_and_masks(images, masks, num_samples=2):
    # Randomly select 'num_samples' number of indices from the available images.
    sample_indices = random.sample(range(images.shape[0]), num_samples)

    # Loop through each sample.
    for i in range(num_samples):
        index = sample_indices[i]  # Get the index of the current sample.

        #  Display the image.
        plt.subplot(num_samples, 2, 2 * i + 1)  # Prepare a subplot.
        plt.imshow(images[index])  # Show the image at the selected index.
        plt.title("Image {}".format(index))  # Set the title for the image.
        plt.axis("off")  # Turn off the axis.

        #  Display the corresponding mask.
        plt.subplot(num_samples, 2, 2 * i + 2)  # Prepare the next subplot.
        plt.imshow(masks[index].squeeze(), cmap='gray')  # Show the mask with a grayscale colormap.
        plt.title("Mask {}".format(index))  # Set the title for the mask.
        plt.axis("off")  # Turn off the axis.

    # Display all the subplots.
    plt.show()

# Display two random images and masks
display_images_and_masks(train_images, train_masks)
# Out:
# train image=(8556, 128, 128, 3) and train_masks=(8556, 128, 128, 1)
# X valid shape =(466, 128, 128, 3) x_test=(233, 128, 128, 3)
# y valid shape =(466, 128, 128, 1)  y_test=(233, 128, 128, 1)

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, UpSampling2D

def build_model(input_shape=(128, 128, 3), num_classes=1, weights_path=None):
    # Load the ResNet50 model with the option to load pre-trained weights and excluding the top (fully connected) layers.
    base_model = ResNet50(weights=weights_path, include_top=False, input_tensor=Input(shape=input_shape))

    # Freeze the layers of the base model to prevent them from being updated during training.
    for layer in base_model.layers:
        layer.trainable = False

    # Start building the custom layers on top of the base model's output.
    x = base_model.output

    # Begin upsampling and adding convolutional layers to build the segmentation head.
    x = UpSampling2D((2, 2))(x)  # Upsample the feature map to increase its spatial dimensions.
    x = Conv2D(512, (3, 3), activation='relu', padding='same')(x)  # Add a convolutional layer with 512 filters.
    x = UpSampling2D((2, 2))(x)  # Continue upsampling.
    x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)  # Add another convolutional layer with 256 filters.
    x = UpSampling2D((2, 2))(x)  # And so on...
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = UpSampling2D((2, 2))(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = UpSampling2D((2, 2))(x)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)

    # Add the final convolutional layer with a filter for each class (in this case, binary, so only 1 filter).
    x = Conv2D(num_classes, (1, 1), activation='sigmoid')(x)

    # Create the model object by specifying the inputs and outputs.
    model = Model(inputs=base_model.input, outputs=x)

    # Compile the model with an optimizer, loss function, and metrics to monitor.
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    # Return the compiled model.
    return model

# %%
model = build_model(weights_path='/content/resnet50/resnet50_weights.h5')

# %%
history = model.fit(train_images, train_masks, batch_size=32, epochs=5, validation_data=(x_valid,y_valid))
# Out:
# Epoch 1/5
# 268/268 [==============================] - 366s 1s/step - loss: 0.0513 - accuracy: 0.9814 - val_loss: 0.0435 - val_accuracy: 0.9849
# Epoch 2/5
# 268/268 [==============================] - 359s 1s/step - loss: 0.0341 - accuracy: 0.9855 - val_loss: 0.0370 - val_accuracy: 0.9856
# Epoch 3/5
# 268/268 [==============================] - 362s 1s/step - loss: 0.0414 - accuracy: 0.9835 - val_loss: 0.0507 - val_accuracy: 0.9861
# Epoch 4/5
# 268/268 [==============================] - 354s 1s/step - loss: 0.0503 - accuracy: 0.9810 - val_loss: 0.0395 - val_accuracy: 0.9853
# Epoch 5/5
# 268/268 [==============================] - 359s 1s/step - loss: 0.0296 - accuracy: 0.9865 - val_loss: 0.0899 - val_accuracy: 0.9735

# %%
def plot_history(history):
    # Plot the training loss values
    plt.plot(history.history['loss'])
    # Plot the validation loss values
    plt.plot(history.history['val_loss'])
    # Set the title of the plot to 'Model loss'
    plt.title('Model loss')
    # Set the y-axis label of the plot to 'Loss'
    plt.ylabel('Loss')
    # Set the x-axis label of the plot to 'Epoch'
    plt.xlabel('Epoch')
    # Add a legend to the plot with labels 'Train' for training loss and 'Validation' for validation loss
    plt.legend(['Train', 'Validation'], loc='upper left')
    # Display the plot
    plt.show()

# %%
plot_history(history)

# %%
# Evaluate the model using the validation dataset.
# 'x_valid' are the input images for validation.
# 'y_valid' are the corresponding ground truth masks for the validation images.
scores = model.evaluate(x_valid, y_valid)

# 'scores' is a list containing the loss as the first element and the accuracy as the second element.
# By accessing 'scores[1]', we retrieve the accuracy of the model on the validation dataset.
accuracy = scores[1]
# Out:
# 15/15 [==============================] - 5s 327ms/step - loss: 0.0899 - accuracy: 0.9735

# %%
prediction = model.predict(x_test)# Use the trained model to make predictions on the test dataset.

# 'x_test' contains the input images for testing.
prediction = model.predict(x_test)

# 'prediction' will contain the output predictions for each input image in 'x_test'.
# For a segmentation model, this would typically be a mask indicating the segmented areas
# Out:
# 8/8 [==============================] - 3s 306ms/step
# 8/8 [==============================] - 2s 286ms/step

# %%
# Evaluate the model using the test data (x_test, y_test)
test_scores = model.evaluate(x_test, y_test)

# test_scores is a list that contains the loss as the first element and the accuracy as the second element.
# Here, we are accessing the second element, which is the accuracy of the model on the test data.
accuracy = test_scores[1]
# Out:
# 8/8 [==============================] - 2s 297ms/step - loss: 0.0819 - accuracy: 0.9770

# %%
image_index = 44

# Load the image and true mask
input_image = x_test[image_index]
true_mask = y_test[image_index]

# Obtain the predicted mask from model2
predicted_mask = model.predict(np.expand_dims(input_image, axis=0))[0]

# Threshold the predicted mask (assuming it's a binary mask)
threshold = 0.5  # Adjust this threshold based on your model's output
predicted_mask_binary = (predicted_mask > threshold).astype(np.uint8)

# Plotting
plt.figure(figsize=(12, 4))

# Plot original image
plt.subplot(1, 3, 1)
plt.imshow(input_image)
plt.title('Original Image')

# Plot true mask
plt.subplot(1, 3, 2)
plt.imshow(true_mask[:, :, 0], cmap='gray')
plt.title('True Mask')

# Plot predicted mask
plt.subplot(1, 3, 3)
plt.imshow(predicted_mask_binary, cmap='gray')
plt.title('Predicted Mask')

plt.show()
# Out:
# 1/1 [==============================] - 0s 68ms/step

# %%
initial_segmentation_results = model.predict(x_test)
# Out:
# 8/8 [==============================] - 2s 292ms/step

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# Define the U-Net model architecture with detailed comments
def unet_model(input_layer):
    # Encoder
    # First convolutional block with 64 filters and relu activation, same padding keeps dimensions unchanged
    conv1 = Conv2D(64, (3, 3), activation='relu', padding='same')(input_layer)
    # First pooling layer reduces spatial dimensions by half (downsampling)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    # Second convolutional block with 128 filters, following the downsampling
    conv2 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool1)
    # Second pooling layer continues to reduce dimensions
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    # Decoder
    # Third convolutional block, placed in the decoder part with upsampling coming next
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    # Upsampling layer to increase the spatial dimensions to match those of conv2
    up1 = UpSampling2D((2, 2))(conv3)
    # Concatenation layer merges feature maps from encoder (conv2) with upsampled maps, crucial for U-Net architecture
    concat1 = concatenate([conv2, up1], axis=-1)

    # Fourth convolutional block after concatenation to refine features
    conv4 = Conv2D(64, (3, 3), activation='relu', padding='same')(concat1)
    # Final upsampling to increase the dimensions to match those of conv1
    up2 = UpSampling2D((2, 2))(conv4)
    # Final concatenation with the very first convolutional layer outputs
    concat2 = concatenate([conv1, up2], axis=-1)

    # Output layer with a single filter and sigmoid activation to produce a binary segmentation map
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(concat2)

    # Create the model instance with specified inputs and outputs
    model = Model(inputs=input_layer, outputs=outputs)
    return model

# Instantiate the U-Net model specifying the input shape
input_layer = Input(shape=(128, 128, 3), name='input_layer_1')
unet_model = unet_model(input_layer)

# Compile the model specifying optimizer, loss function, and metrics for evaluation
unet_model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy'])

# Train the U-Net model on the provided training data, also include validation data for evaluating performance
unet_model.fit(train_images, train_masks, batch_size=32, epochs=5, validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/5
# 268/268 [==============================] - 240s 893ms/step - loss: 0.1159 - accuracy: 0.9797 - val_loss: 0.0423 - val_accuracy: 0.9837
# Epoch 2/5
# 268/268 [==============================] - 242s 902ms/step - loss: 0.0369 - accuracy: 0.9861 - val_loss: 0.0352 - val_accuracy: 0.9855
# Epoch 3/5
# 268/268 [==============================] - 242s 902ms/step - loss: 0.0328 - accuracy: 0.9870 - val_loss: 0.0326 - val_accuracy: 0.9863
# Epoch 4/5
# 268/268 [==============================] - 241s 901ms/step - loss: 0.0306 - accuracy: 0.9876 - val_loss: 0.0311 - val_accuracy: 0.9869
# Epoch 5/5
# 268/268 [==============================] - 241s 900ms/step - loss: 0.0289 - accuracy: 0.9882 - val_loss: 0.0314 - val_accuracy: 0.9866

# %%
def plot_history(history):
    # Plot the training loss values
    plt.plot(history.history['loss'])
    # Plot the validation loss values
    plt.plot(history.history['val_loss'])
    # Set the title of the plot to 'Model loss'
    plt.title('Model loss')
    # Set the y-axis label of the plot to 'Loss'
    plt.ylabel('Loss')
    # Set the x-axis label of the plot to 'Epoch'
    plt.xlabel('Epoch')
    # Add a legend to the plot with labels 'Train' for training loss and 'Validation' for validation loss
    plt.legend(['Train', 'Validation'], loc='upper left')
    # Display the plot
    plt.show()

# %%
evaluation = unet_model.evaluate(x_test, y_test)
# Out:
# 8/8 [==============================] - 1s 170ms/step - loss: 0.0301 - accuracy: 0.9872
